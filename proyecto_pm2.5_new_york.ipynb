# %% [markdown]
# # 🌇 Análisis de la Contaminación por PM2.5 en Nueva York (2020–2024)
#
# > _Una exploración visual y técnica del aire que respiramos._
#
# Este proyecto examina cómo la concentración de **material particulado fino (PM2.5)** ha evolucionado en la ciudad de Nueva York durante cinco años. A través de visualizaciones claras y análisis estadísticos, se revela:
#
# - La variabilidad mensual del PM2.5 y sus días extremos.
# - El comportamiento estacional y la presencia de outliers en cada mes.
# - La relación directa entre los valores de **PM2.5** y el **Índice de Calidad del Aire (AQI)** —mostrando cómo los datos técnicos se traducen en riesgos reales para la salud.
#
# 🧠 Visualizaciones clave:
# - **Boxplots mensuales** que muestran la dispersión y anomalías del PM2.5.
# - **Scatterplots y líneas temporales** que conectan la evolución del aire con el índice sanitario AQI.
# - **Comparativas por año** para identificar patrones y eventos excepcionales (como el pico en 2023).
#
# 📌 Este análisis está diseñado no sólo para comprender los datos, sino para **contar una historia ambiental** basada en evidencia. Desde el rigor técnico hasta la visualización accesible —la ciencia se transforma en narrativa urbana.
#
# ---
#
# 🧪 *Autor del análisis:* César Díaz
# 📍 *Ubicación de estudio:* Ciudad de Nueva York
# 📅 *Período:* 2020–2024
# 📘 *Tecnologías:* Python · Pandas · Seaborn · Matplotlib
#
# ---

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\mjcd1\anaconda3\envs\unicornenv\python.exe

# %%
from sqlalchemy import create_engine
from getpass import getpass
import pandas as pd

# Solicitar credenciales de forma segura
usuario = input("Introduce tu usuario de MySQL: ")
contraseña = getpass("Introduce tu contraseña de MySQL: ")
host = input("Introduce el host (por defecto 'localhost'): ") or "localhost"
bd = input("Introduce el nombre de la base de datos: ")

# Crear motor de conexión con SQLAlchemy
engine = create_engine(f"mysql+mysqlconnector://{usuario}:{contraseña}@{host}/{bd}")

# Probar la conexión
consulta = "SELECT * FROM `pm2.5_new_york_2020`"
df_2020 = pd.read_sql(consulta, con=engine)
#df_2020["Date"] = pd.to_datetime(df_2020["Date"], errors="coerce", dayfirst=False)

# Mostrar resultados
print("Primeros registros de la tabla pm2.5_new_york_2020:")
display(df_2020)
# Out:
# Introduce tu usuario de MySQL:  root
# Introduce tu contraseña de MySQL:  ········
# Introduce el host (por defecto 'localhost'):  localhost
# Introduce el nombre de la base de datos:  pm25_nyc
# Primeros registros de la tabla pm2.5_new_york_2020:
#              Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0      2020-01-01    AQS  360010005    1                             1.9
# 1      2020-01-04    AQS  360010005    1                             9.6
# 2      2020-01-07    AQS  360010005    1                             5.0
# 3      2020-01-10    AQS  360010005    1                             5.2
# 4      2020-01-13    AQS  360010005    1                             4.0
# ...           ...    ...        ...  ...                             ...
# 12503  2020-12-27    AQS  361192004    3                            11.0
# 12504  2020-12-28    AQS  361192004    3                            10.7
# 12505  2020-12-29    AQS  361192004    3                             5.8
# 12506  2020-12-30    AQS  361192004    3                             5.6
# 12507  2020-12-31    AQS  361192004    3                             9.3
#
#           Units  Daily AQI Value            Local Site Name  Daily Obs Count  \
# 0      ug/m3 LC               11  ALBANY COUNTY HEALTH DEPT                1
# 1      ug/m3 LC               52  ALBANY COUNTY HEALTH DEPT                1
# 2      ug/m3 LC               28  ALBANY COUNTY HEALTH DEPT                1
# 3      ug/m3 LC               29  ALBANY COUNTY HEALTH DEPT                1
# 4      ug/m3 LC               22  ALBANY COUNTY HEALTH DEPT                1
# ...         ...              ...                        ...              ...
# 12503  ug/m3 LC               55               WHITE PLAINS                1
# 12504  ug/m3 LC               54               WHITE PLAINS                1
# 12505  ug/m3 LC               32               WHITE PLAINS                1
# 12506  ug/m3 LC               31               WHITE PLAINS                1
# 12507  ug/m3 LC               51               WHITE PLAINS                1
#
#        Percent Complete  ...  Method Code  \
# 0                 100.0  ...          145
# 1                 100.0  ...          145
# 2                 100.0  ...          145
# 3                 100.0  ...          145
# 4                 100.0  ...          145
# ...                 ...  ...          ...
# 12503             100.0  ...          702
# 12504             100.0  ...          702
# 12505             100.0  ...          702
# 12506             100.0  ...          702
# 12507             100.0  ...          702
#
#                                       Method Description  CBSA Code  \
# 0      R & P Model 2025 PM-2.5 Sequential Air Sampler...      10580
# 1      R & P Model 2025 PM-2.5 Sequential Air Sampler...      10580
# 2      R & P Model 2025 PM-2.5 Sequential Air Sampler...      10580
# 3      R & P Model 2025 PM-2.5 Sequential Air Sampler...      10580
# 4      R & P Model 2025 PM-2.5 Sequential Air Sampler...      10580
# ...                                                  ...        ...
# 12503                      PM2.5 SCC w/Correction Factor      35620
# 12504                      PM2.5 SCC w/Correction Factor      35620
# 12505                      PM2.5 SCC w/Correction Factor      35620
# 12506                      PM2.5 SCC w/Correction Factor      35620
# 12507                      PM2.5 SCC w/Correction Factor      35620
#
#                                    CBSA Name  State FIPS Code     State  \
# 0                Albany-Schenectady-Troy, NY               36  New York
# 1                Albany-Schenectady-Troy, NY               36  New York
# 2                Albany-Schenectady-Troy, NY               36  New York
# 3                Albany-Schenectady-Troy, NY               36  New York
# 4                Albany-Schenectady-Troy, NY               36  New York
# ...                                      ...              ...       ...
# 12503  New York-Newark-Jersey City, NY-NJ-PA               36  New York
# 12504  New York-Newark-Jersey City, NY-NJ-PA               36  New York
# 12505  New York-Newark-Jersey City, NY-NJ-PA               36  New York
# 12506  New York-Newark-Jersey City, NY-NJ-PA               36  New York
# 12507  New York-Newark-Jersey City, NY-NJ-PA               36  New York
#
#        County FIPS Code       County Site Latitude Site Longitude
# 0                   001       Albany      42.64225      -73.75464
# 1                   001       Albany      42.64225      -73.75464
# 2                   001       Albany      42.64225      -73.75464
# 3                   001       Albany      42.64225      -73.75464
# 4                   001       Albany      42.64225      -73.75464
# ...                 ...          ...           ...            ...
# 12503               119  Westchester      41.05192      -73.76366
# 12504               119  Westchester      41.05192      -73.76366
# 12505               119  Westchester      41.05192      -73.76366
# 12506               119  Westchester      41.05192      -73.76366
# 12507               119  Westchester      41.05192      -73.76366
#
# [12508 rows x 22 columns]

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12508 entries, 0 to 12507
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            12508 non-null  object
#  1   Source                          12508 non-null  object
#  2   Site ID                         12508 non-null  int64
#  3   POC                             12508 non-null  int64
#  4   Daily Mean PM2.5 Concentration  12508 non-null  float64
#  5   Units                           12508 non-null  object
#  6   Daily AQI Value                 12508 non-null  int64
#  7   Local Site Name                 12508 non-null  object
#  8   Daily Obs Count                 12508 non-null  int64
#  9   Percent Complete                12508 non-null  float64
#  10  AQS Parameter Code              12508 non-null  int64
#  11  AQS Parameter Description       12508 non-null  object
#  12  Method Code                     12508 non-null  int64
#  13  Method Description              12508 non-null  object
#  14  CBSA Code                       12508 non-null  int64
#  15  CBSA Name                       12508 non-null  object
#  16  State FIPS Code                 12508 non-null  int64
#  17  State                           12508 non-null  object
#  18  County FIPS Code                12508 non-null  object
#  19  County                          12508 non-null  object
#  20  Site Latitude                   12508 non-null  float64
#  21  Site Longitude                  12508 non-null  float64
# dtypes: float64(4), int64(8), object(10)
# memory usage: 2.1+ MB

# %%
# 2020
consulta_2020 = "SELECT * FROM `pm2.5_new_york_2020`"
df_2020 = pd.read_sql(consulta_2020, con=engine)
df_2020["Date"] = pd.to_datetime(df_2020["Date"])

# 2021
consulta_2021 = "SELECT * FROM `pm2.5_new_york_2021`"
df_2021 = pd.read_sql(consulta_2021, con=engine)
df_2021["Date"] = pd.to_datetime(df_2021["Date"])

# 2022
consulta_2022 = "SELECT * FROM `pm2.5_new_york_2022`"
df_2022 = pd.read_sql(consulta_2022, con=engine)
df_2022["Date"] = pd.to_datetime(df_2022["Date"])

# 2023
consulta_2023 = "SELECT * FROM `pm2.5_new_york_2023`"
df_2023 = pd.read_sql(consulta_2023, con=engine)
df_2023["Date"] = pd.to_datetime(df_2023["Date"])

# 2024
consulta_2024 = "SELECT * FROM `pm2.5_new_york_2024`"
df_2024 = pd.read_sql(consulta_2024, con=engine)
df_2024["Date"] = pd.to_datetime(df_2024["Date"])

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12508 entries, 0 to 12507
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            12508 non-null  datetime64[ns]
#  1   Source                          12508 non-null  object
#  2   Site ID                         12508 non-null  int64
#  3   POC                             12508 non-null  int64
#  4   Daily Mean PM2.5 Concentration  12508 non-null  float64
#  5   Units                           12508 non-null  object
#  6   Daily AQI Value                 12508 non-null  int64
#  7   Local Site Name                 12508 non-null  object
#  8   Daily Obs Count                 12508 non-null  int64
#  9   Percent Complete                12508 non-null  float64
#  10  AQS Parameter Code              12508 non-null  int64
#  11  AQS Parameter Description       12508 non-null  object
#  12  Method Code                     12508 non-null  int64
#  13  Method Description              12508 non-null  object
#  14  CBSA Code                       12508 non-null  int64
#  15  CBSA Name                       12508 non-null  object
#  16  State FIPS Code                 12508 non-null  int64
#  17  State                           12508 non-null  object
#  18  County FIPS Code                12508 non-null  object
#  19  County                          12508 non-null  object
#  20  Site Latitude                   12508 non-null  float64
#  21  Site Longitude                  12508 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 2.1+ MB

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13032 entries, 0 to 13031
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            13032 non-null  datetime64[ns]
#  1   Source                          13032 non-null  object
#  2   Site ID                         13032 non-null  int64
#  3   POC                             13032 non-null  int64
#  4   Daily Mean PM2.5 Concentration  13032 non-null  float64
#  5   Units                           13032 non-null  object
#  6   Daily AQI Value                 13032 non-null  int64
#  7   Local Site Name                 13032 non-null  object
#  8   Daily Obs Count                 13032 non-null  int64
#  9   Percent Complete                13032 non-null  float64
#  10  AQS Parameter Code              13032 non-null  int64
#  11  AQS Parameter Description       13032 non-null  object
#  12  Method Code                     13032 non-null  int64
#  13  Method Description              13032 non-null  object
#  14  CBSA Code                       13032 non-null  int64
#  15  CBSA Name                       13032 non-null  object
#  16  State FIPS Code                 13032 non-null  int64
#  17  State                           13032 non-null  object
#  18  County FIPS Code                13032 non-null  object
#  19  County                          13032 non-null  object
#  20  Site Latitude                   13032 non-null  float64
#  21  Site Longitude                  13032 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 2.2+ MB

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12775 entries, 0 to 12774
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            12775 non-null  datetime64[ns]
#  1   Source                          12775 non-null  object
#  2   Site ID                         12775 non-null  int64
#  3   POC                             12775 non-null  int64
#  4   Daily Mean PM2.5 Concentration  12775 non-null  float64
#  5   Units                           12775 non-null  object
#  6   Daily AQI Value                 12775 non-null  int64
#  7   Local Site Name                 12775 non-null  object
#  8   Daily Obs Count                 12775 non-null  int64
#  9   Percent Complete                12775 non-null  float64
#  10  AQS Parameter Code              12775 non-null  int64
#  11  AQS Parameter Description       12775 non-null  object
#  12  Method Code                     12775 non-null  int64
#  13  Method Description              12775 non-null  object
#  14  CBSA Code                       12775 non-null  int64
#  15  CBSA Name                       12775 non-null  object
#  16  State FIPS Code                 12775 non-null  int64
#  17  State                           12775 non-null  object
#  18  County FIPS Code                12775 non-null  object
#  19  County                          12775 non-null  object
#  20  Site Latitude                   12775 non-null  float64
#  21  Site Longitude                  12775 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 2.1+ MB

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11912 entries, 0 to 11911
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            11912 non-null  datetime64[ns]
#  1   Source                          11912 non-null  object
#  2   Site ID                         11912 non-null  int64
#  3   POC                             11912 non-null  int64
#  4   Daily Mean PM2.5 Concentration  11912 non-null  float64
#  5   Units                           11912 non-null  object
#  6   Daily AQI Value                 11912 non-null  int64
#  7   Local Site Name                 11912 non-null  object
#  8   Daily Obs Count                 11912 non-null  int64
#  9   Percent Complete                11912 non-null  float64
#  10  AQS Parameter Code              11912 non-null  int64
#  11  AQS Parameter Description       11912 non-null  object
#  12  Method Code                     11912 non-null  int64
#  13  Method Description              11912 non-null  object
#  14  CBSA Code                       11912 non-null  int64
#  15  CBSA Name                       11912 non-null  object
#  16  State FIPS Code                 11912 non-null  int64
#  17  State                           11912 non-null  object
#  18  County FIPS Code                11912 non-null  object
#  19  County                          11912 non-null  object
#  20  Site Latitude                   11912 non-null  float64
#  21  Site Longitude                  11912 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 2.0+ MB

# %%
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9793 entries, 0 to 9792
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            9793 non-null   datetime64[ns]
#  1   Source                          9793 non-null   object
#  2   Site ID                         9793 non-null   int64
#  3   POC                             9793 non-null   int64
#  4   Daily Mean PM2.5 Concentration  9793 non-null   float64
#  5   Units                           9793 non-null   object
#  6   Daily AQI Value                 9793 non-null   int64
#  7   Local Site Name                 9793 non-null   object
#  8   Daily Obs Count                 9793 non-null   int64
#  9   Percent Complete                9793 non-null   float64
#  10  AQS Parameter Code              9793 non-null   int64
#  11  AQS Parameter Description       9793 non-null   object
#  12  Method Code                     9793 non-null   int64
#  13  Method Description              9793 non-null   object
#  14  CBSA Code                       9793 non-null   int64
#  15  CBSA Name                       9793 non-null   object
#  16  State FIPS Code                 9793 non-null   int64
#  17  State                           9793 non-null   object
#  18  County FIPS Code                9793 non-null   object
#  19  County                          9793 non-null   object
#  20  Site Latitude                   9793 non-null   float64
#  21  Site Longitude                  9793 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(9)
# memory usage: 1.6+ MB

# %% [markdown]
# ## **📌 Evolución anual de PM2.5 (2020–2024)**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Consolidar los años
df_total = pd.concat([df_2020, df_2021, df_2022, df_2023, df_2024], ignore_index=True)

# Agrupar por año
df_total['Year'] = df_total['Date'].dt.year
pm25_yearly = df_total.groupby('Year')['Daily Mean PM2.5 Concentration'].mean()

# Graficar
plt.figure(figsize=(10,5))
pm25_yearly.plot(marker='o', linestyle='-')
plt.title('Evolución promedio anual de PM2.5 en Nueva York (2020–2024)')
plt.xlabel('Año')
plt.ylabel('PM2.5 (µg/m³)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **🧪 Distribución mensual de PM2.5 (Boxplot 2020–2024)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Combinar todos los años
df_total = pd.concat([df_2020, df_2021, df_2022, df_2023, df_2024], ignore_index=True)

# Extraer mes
df_total['Month'] = df_total['Date'].dt.month

# Graficar distribución mensual
plt.figure(figsize=(12,6))
sns.boxplot(data=df_total, x='Month', y='Daily Mean PM2.5 Concentration', palette='coolwarm')
plt.title('Distribución mensual de PM2.5 en Nueva York (2020–2024)', fontsize=14)
plt.xlabel('Mes')
plt.ylabel('PM2.5 (µg/m³)')
plt.grid(True)
plt.xticks(ticks=range(12), labels=['Ene','Feb','Mar','Abr','May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'])
plt.tight_layout()
plt.savefig('images/boxplot_pm25_month.png', dpi=300)
plt.show()
# Out:
# C:\Users\mjcd1\AppData\Local\Temp\ipykernel_6320\3592747948.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_total, x='Month', y='Daily Mean PM2.5 Concentration', palette='coolwarm')

# %% [markdown]
# ## **📈 1. Gráfico de líneas con medianas mensuales**
# - Este tipo de gráfico muestra claramente cómo cambian los valores centrales entre meses:

# %%
df_total['Month'] = df_total['Date'].dt.month
monthly_median = df_total.groupby('Month')['Daily Mean PM2.5 Concentration'].median()

monthly_median.plot(marker='o', linestyle='-', figsize=(10,5), title='Mediana mensual de PM2.5 (2020–2024)')
# Out:
# <Axes: title={'center': 'Mediana mensual de PM2.5 (2020–2024)'}, xlabel='Month'>

# %% [markdown]
# ## **🟦 2. Gráfico de barras con medias o medianas**
# - Aún más claro para presentaciones o análisis comparativos:

# %%
monthly_median.plot(kind='bar', color='steelblue', figsize=(10,5), title='Mediana mensual de PM2.5')
# Out:
# <Axes: title={'center': 'Mediana mensual de PM2.5'}, xlabel='Month'>

# %% [markdown]
# ## **💡 ¿Cómo saber cuántos son realmente outliers?**
# - Podemos calcularlos mes por mes así:

# %%
outliers_por_mes = {}

for mes in range(1, 13):
    df_mes = df_total[df_total['Month'] == mes]
    q1 = df_mes['Daily Mean PM2.5 Concentration'].quantile(0.25)
    q3 = df_mes['Daily Mean PM2.5 Concentration'].quantile(0.75)
    iqr = q3 - q1
    limite_superior = q3 + 1.5 * iqr
    outliers = df_mes[df_mes['Daily Mean PM2.5 Concentration'] > limite_superior]
    
    outliers_por_mes[mes] = len(outliers)

# Ver cuántos hay por mes
print(outliers_por_mes)
# Out:
# {1: 210, 2: 131, 3: 274, 4: 192, 5: 141, 6: 366, 7: 336, 8: 142, 9: 223, 10: 144, 11: 272, 12: 183}

# %% [markdown]
# ## **📍 Versión inicial: PM2.5 por día**

# %%
df_total['Year'] = df_total['Date'].dt.year

plt.figure(figsize=(14,6))
sns.scatterplot(data=df_total, x='Date', y='Daily Mean PM2.5 Concentration', hue='Year', palette='Spectral', alpha=0.6)
plt.title('PM2.5 en Nueva York (color por año)')
plt.ylabel('Concentración (µg/m³)')
plt.xlabel('Fecha')
plt.grid(True)
plt.tight_layout()
plt.savefig('images/scatter_pm25_years.png', dpi=300)
plt.show()

# %% [markdown]
# ## **🎯 1️⃣ Scatterplot PM2.5 vs AQI con color por año**

# %% [markdown]
# ## 📊 Relación entre PM2.5 y AQI (2020–2024)
#
# Este gráfico revela cómo la concentración de PM2.5 se relaciona con el AQI, un índice que traduce los niveles contaminantes en riesgos de salud pública.
#
# 🧠 Observaciones clave:
# - 2023 presenta los valores más altos en PM2.5 y AQI.
# - Existe una correlación positiva clara.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_total['Year'] = df_total['Date'].dt.year

plt.figure(figsize=(12,6))
sns.scatterplot(data=df_total, 
                x='Daily Mean PM2.5 Concentration', 
                y='Daily AQI Value',
                hue='Year',
                palette='Spectral',
                alpha=0.6)

plt.title('Relación entre PM2.5 y AQI con color por año (2020–2024)', fontsize=14)
plt.xlabel('Concentración PM2.5 (µg/m³)')
plt.ylabel('Índice AQI')
plt.grid(True)
plt.tight_layout()
plt.savefig('images/scatter_pm25_vs_aqi.png', dpi=300)
plt.show()

# %% [markdown]
# ## **📈 2️⃣ Doble línea: evolución temporal de PM2.5 y AQI**

# %%
import matplotlib.pyplot as plt

# Agrupar por día para promediar si hay más de una estación
df_diario = df_total.groupby('Date')[['Daily Mean PM2.5 Concentration', 'Daily AQI Value']].mean()

plt.figure(figsize=(14,6))
plt.plot(df_diario.index, df_diario['Daily Mean PM2.5 Concentration'], label='PM2.5 (µg/m³)', color='firebrick', alpha=0.6)
plt.plot(df_diario.index, df_diario['Daily AQI Value'], label='AQI', color='darkblue', alpha=0.6)
plt.title('Evolución diaria de PM2.5 y AQI en Nueva York (2020–2024)', fontsize=14)
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('images/line_pm25_aqi.png', dpi=300)
plt.show()

# %% [markdown]
# ### 📌 Conclusión del gráfico temporal de PM2.5 y AQI
#
# Este gráfico muestra cómo la calidad del aire en Nueva York ha fluctuado diariamente entre 2020 y 2024, y cómo el **PM2.5 y el AQI se elevan en paralelo**, revelando una correlación estrecha entre la concentración de partículas y el riesgo para la salud pública.
#
# ### 🧠 Insights clave:
# - Los **picos más agudos en 2023** reflejan eventos extremos, posiblemente relacionados con incendios forestales o fenómenos climáticos.
# - El patrón estacional es evidente: se observan **repuntes en invierno**, lo que podría vincularse con calefacción urbana o inversión térmica.
# - Las curvas mantienen una relación coherente, lo que confirma que el **AQI responde directamente al comportamiento del PM2.5**.
#
# Este análisis temporal complementa la perspectiva del gráfico de dispersión y permite entender no solo el impacto puntual, sino la dinámica respiratoria de una ciudad entera.
